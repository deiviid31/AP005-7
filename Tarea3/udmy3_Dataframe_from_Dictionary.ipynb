# %% [markdown]
# La siguiente línea es para **importar la librería pandas**.

# %%
import pandas as pd

# %% [markdown]
# La siguiente línea es para **crear un diccionario con los datos de nombre, edad y género de tres personas**.

# %%
data = {"name": ["Sally", "Jhon", "Kim"], "age": [4, 6 ,7], "gender": ["female", "male", "male"]}

# %% [markdown]
# La siguiente línea es para **crear un DataFrame de pandas a partir del diccionario**.

# %%
pd.DataFrame(data)
# Out:
#     name  age  gender
# 0  Sally    4  female
# 1   Jhon    6    male
# 2    Kim    7    male

# %% [markdown]
# La siguiente línea es para **crear el mismo DataFrame, pero asignando un índice personalizado (Kid1, Kid2, Kid3)**.

# %%
pd.DataFrame(data, index = ["Kid1", "Kid2", "Kid3"])
# Out:
#        name  age  gender
# Kid1  Sally    4  female
# Kid2   Jhon    6    male
# Kid3    Kim    7    male
